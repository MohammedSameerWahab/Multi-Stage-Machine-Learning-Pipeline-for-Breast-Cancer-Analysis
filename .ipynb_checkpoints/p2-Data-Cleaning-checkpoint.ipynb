# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("brca_data_w_subtypes.csv")

# %%
#head

df.head()
# Out:
#    rs_CLEC3A    rs_CPB1  rs_SCGB2A2  rs_SCGB1D2    rs_TFF1   rs_MUCL1  \
# 0   0.892818   6.580103   14.123672   10.606501  13.189237   6.649466
# 1   0.000000   3.691311   17.116090   15.517231   9.867616   9.691667
# 2   3.748150   4.375255    9.658123    5.326983  12.109539  11.644307
# 3   0.000000  18.235519   18.535480   14.533584  14.078992   8.913760
# 4   0.000000   4.583724   15.711865   12.804521   8.881669   8.430028
#
#     rs_GSTM1     rs_PIP  rs_ADIPOQ   rs_ADH1B  ...  pp_p62.LCK.ligand  \
# 0  10.520335  10.338490  10.248379  10.229970  ...          -0.691766
# 1   8.179522   7.911723   1.289598   1.818891  ...           0.279067
# 2  10.517330   5.114925  11.975349  11.911437  ...           0.219910
# 3  10.557465  13.304434   8.205059   9.211476  ...          -0.266554
# 4  12.964607   6.806517   4.294341   5.385714  ...          -0.441542
#
#    pp_p70S6K  pp_p70S6K.pT389  pp_p90RSK  pp_p90RSK.pT359.S363  vital.status  \
# 0  -0.337863        -0.178503   0.011638             -0.207257             0
# 1   0.292925        -0.155242  -0.089365              0.267530             0
# 2   0.308110        -0.190794  -0.222150             -0.198518             0
# 3  -0.079871        -0.463237   0.522998             -0.046902             0
# 4  -0.152317         0.511386  -0.096482              0.037473             0
#
#    PR.Status  ER.Status  HER2.Final.Status              histological.type
# 0   Positive   Positive           Negative  infiltrating ductal carcinoma
# 1   Positive   Negative           Negative  infiltrating ductal carcinoma
# 2   Positive   Positive           Negative  infiltrating ductal carcinoma
# 3   Positive   Positive           Negative  infiltrating ductal carcinoma
# 4   Positive   Positive           Negative  infiltrating ductal carcinoma
#
# [5 rows x 1941 columns]

# %%
#shape

df.shape
# Out:
# (705, 1941)

# %%
#info()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Columns: 1941 entries, rs_CLEC3A to histological.type
# dtypes: float64(827), int64(1110), object(4)
# memory usage: 10.4+ MB

# %%
#finding missing values
df.isnull().sum()
# Out:
# rs_CLEC3A              0
# rs_CPB1                0
# rs_SCGB2A2             0
# rs_SCGB1D2             0
# rs_TFF1                0
#                     ...
# vital.status           0
# PR.Status            122
# ER.Status            122
# HER2.Final.Status    145
# histological.type      0
# Length: 1941, dtype: int64

# %%
#percentage of missing values
df.isnull().sum()/df.shape[0]*100
# Out:
# rs_CLEC3A             0.000000
# rs_CPB1               0.000000
# rs_SCGB2A2            0.000000
# rs_SCGB1D2            0.000000
# rs_TFF1               0.000000
#                        ...
# vital.status          0.000000
# PR.Status            17.304965
# ER.Status            17.304965
# HER2.Final.Status    20.567376
# histological.type     0.000000
# Length: 1941, dtype: float64

# %%
#finding duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#identifying garbage values
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("***"*10)
# Out:
# PR.Status
# Positive                       353
# Negative                       193
# Not Performed                   28
# Performed but Not Available      5
# Indeterminate                    4
# Name: count, dtype: int64
# ******************************
# ER.Status
# Positive                       414
# Negative                       135
# Not Performed                   27
# Performed but Not Available      5
# Indeterminate                    2
# Name: count, dtype: int64
# ******************************
# HER2.Final.Status
# Negative         457
# Positive          86
# Equivocal          9
# Not Available      8
# Name: count, dtype: int64
# ******************************
# histological.type
# infiltrating ductal carcinoma     574
# infiltrating lobular carcinoma    131
# Name: count, dtype: int64
# ******************************

# %%
# Create a new DataFrame without the missing rows
df_cleaned = df.dropna()

print("DataFrame after dropping rows with any missing value:")
df_cleaned
# Out:
# DataFrame after dropping rows with any missing value:
#      rs_CLEC3A    rs_CPB1  rs_SCGB2A2  rs_SCGB1D2    rs_TFF1   rs_MUCL1  \
# 0     0.892818   6.580103   14.123672   10.606501  13.189237   6.649466
# 1     0.000000   3.691311   17.116090   15.517231   9.867616   9.691667
# 2     3.748150   4.375255    9.658123    5.326983  12.109539  11.644307
# 3     0.000000  18.235519   18.535480   14.533584  14.078992   8.913760
# 4     0.000000   4.583724   15.711865   12.804521   8.881669   8.430028
# ..         ...        ...         ...         ...        ...        ...
# 644   0.000000  14.652475    6.430018    2.487152  10.896235   2.487152
# 645   0.000000   4.071531    3.128508    5.467426   0.000000   0.718438
# 647   3.186199  11.624534    8.096817    4.858956   9.683010   9.276432
# 648  15.582967  10.151592   15.638541   14.126165  12.447517  16.541921
# 649   0.000000   5.093780   15.999704   13.844006  11.539494  13.139496
#
#       rs_GSTM1     rs_PIP  rs_ADIPOQ   rs_ADH1B  ...  pp_p62.LCK.ligand  \
# 0    10.520335  10.338490  10.248379  10.229970  ...          -0.691766
# 1     8.179522   7.911723   1.289598   1.818891  ...           0.279067
# 2    10.517330   5.114925  11.975349  11.911437  ...           0.219910
# 3    10.557465  13.304434   8.205059   9.211476  ...          -0.266554
# 4    12.964607   6.806517   4.294341   5.385714  ...          -0.441542
# ..         ...        ...        ...        ...  ...                ...
# 644   1.507262   3.591691   9.853473   8.579071  ...           0.143937
# 645   7.640049   2.959232   0.718438   0.000000  ...           0.866684
# 647   0.000000   4.104681  10.952462  10.785635  ...          -0.506134
# 648   2.528146  12.756991   7.870444   7.952345  ...           0.720128
# 649   1.073820  13.300868   6.095994   7.043729  ...          -0.160632
#
#      pp_p70S6K  pp_p70S6K.pT389  pp_p90RSK  pp_p90RSK.pT359.S363  \
# 0    -0.337863        -0.178503   0.011638             -0.207257
# 1     0.292925        -0.155242  -0.089365              0.267530
# 2     0.308110        -0.190794  -0.222150             -0.198518
# 3    -0.079871        -0.463237   0.522998             -0.046902
# 4    -0.152317         0.511386  -0.096482              0.037473
# ..         ...              ...        ...                   ...
# 644  -0.187309        -0.005034  -0.511851              0.010582
# 645  -0.362491        -0.225097  -0.098282             -0.057920
# 647  -0.369786         0.967447  -0.201545              0.482839
# 648  -0.208679         0.003550  -0.254628             -0.092632
# 649  -0.688076         0.067496  -0.018579              0.072714
#
#      vital.status  PR.Status  ER.Status  HER2.Final.Status  \
# 0               0   Positive   Positive           Negative
# 1               0   Positive   Negative           Negative
# 2               0   Positive   Positive           Negative
# 3               0   Positive   Positive           Negative
# 4               0   Positive   Positive           Negative
# ..            ...        ...        ...                ...
# 644             0   Positive   Positive           Negative
# 645             0   Negative   Negative           Negative
# 647             0   Positive   Positive           Positive
# 648             0   Positive   Positive           Negative
# 649             0   Positive   Positive           Negative
#
#                   histological.type
# 0     infiltrating ductal carcinoma
# 1     infiltrating ductal carcinoma
# 2     infiltrating ductal carcinoma
# 3     infiltrating ductal carcinoma
# 4     infiltrating ductal carcinoma
# ..                              ...
# 644   infiltrating ductal carcinoma
# 645   infiltrating ductal carcinoma
# 647   infiltrating ductal carcinoma
# 648   infiltrating ductal carcinoma
# 649  infiltrating lobular carcinoma
#
# [560 rows x 1941 columns]

# %%
# 1. Define the list of string values you want to remove.
values_to_remove = ["Not Performed", "Performed but Not Available", "Indeterminate", "Not Available"]

# 2. Create a boolean mask.
# This checks every cell. If a cell contains one of the values_to_remove, it becomes True.
# .any(axis=1) then marks the entire row as True if it contains at least one True value.
rows_to_drop_mask = df_cleaned.isin(values_to_remove).any(axis=1)

# 3. Filter the DataFrame.
# The '~' (tilde) operator inverts the boolean mask, so you keep only the rows that are False (i.e., rows without the specified values).
df_further_cleaned = df_cleaned[~rows_to_drop_mask]


# --- Display the Result ---
print("Cleaned DataFrame:")
print(df_further_cleaned)
# Out:
# Cleaned DataFrame:
#      rs_CLEC3A    rs_CPB1  rs_SCGB2A2  rs_SCGB1D2    rs_TFF1   rs_MUCL1  \
# 0     0.892818   6.580103   14.123672   10.606501  13.189237   6.649466
# 1     0.000000   3.691311   17.116090   15.517231   9.867616   9.691667
# 2     3.748150   4.375255    9.658123    5.326983  12.109539  11.644307
# 3     0.000000  18.235519   18.535480   14.533584  14.078992   8.913760
# 4     0.000000   4.583724   15.711865   12.804521   8.881669   8.430028
# ..         ...        ...         ...         ...        ...        ...
# 644   0.000000  14.652475    6.430018    2.487152  10.896235   2.487152
# 645   0.000000   4.071531    3.128508    5.467426   0.000000   0.718438
# 647   3.186199  11.624534    8.096817    4.858956   9.683010   9.276432
# 648  15.582967  10.151592   15.638541   14.126165  12.447517  16.541921
# 649   0.000000   5.093780   15.999704   13.844006  11.539494  13.139496
#
#       rs_GSTM1     rs_PIP  rs_ADIPOQ   rs_ADH1B  ...  pp_p62.LCK.ligand  \
# 0    10.520335  10.338490  10.248379  10.229970  ...          -0.691766
# 1     8.179522   7.911723   1.289598   1.818891  ...           0.279067
# 2    10.517330   5.114925  11.975349  11.911437  ...           0.219910
# 3    10.557465  13.304434   8.205059   9.211476  ...          -0.266554
# 4    12.964607   6.806517   4.294341   5.385714  ...          -0.441542
# ..         ...        ...        ...        ...  ...                ...
# 644   1.507262   3.591691   9.853473   8.579071  ...           0.143937
# 645   7.640049   2.959232   0.718438   0.000000  ...           0.866684
# 647   0.000000   4.104681  10.952462  10.785635  ...          -0.506134
# 648   2.528146  12.756991   7.870444   7.952345  ...           0.720128
# 649   1.073820  13.300868   6.095994   7.043729  ...          -0.160632
#
#      pp_p70S6K  pp_p70S6K.pT389  pp_p90RSK  pp_p90RSK.pT359.S363  \
# 0    -0.337863        -0.178503   0.011638             -0.207257
# 1     0.292925        -0.155242  -0.089365              0.267530
# 2     0.308110        -0.190794  -0.222150             -0.198518
# 3    -0.079871        -0.463237   0.522998             -0.046902
# 4    -0.152317         0.511386  -0.096482              0.037473
# ..         ...              ...        ...                   ...
# 644  -0.187309        -0.005034  -0.511851              0.010582
# 645  -0.362491        -0.225097  -0.098282             -0.057920
# 647  -0.369786         0.967447  -0.201545              0.482839
# 648  -0.208679         0.003550  -0.254628             -0.092632
# 649  -0.688076         0.067496  -0.018579              0.072714
#
#      vital.status  PR.Status  ER.Status  HER2.Final.Status  \
# 0               0   Positive   Positive           Negative
# 1               0   Positive   Negative           Negative
# 2               0   Positive   Positive           Negative
# 3               0   Positive   Positive           Negative
# 4               0   Positive   Positive           Negative
# ..            ...        ...        ...                ...
# 644             0   Positive   Positive           Negative
# 645             0   Negative   Negative           Negative
# 647             0   Positive   Positive           Positive
# 648             0   Positive   Positive           Negative
# 649             0   Positive   Positive           Negative
#
#                   histological.type
# 0     infiltrating ductal carcinoma
# 1     infiltrating ductal carcinoma
# 2     infiltrating ductal carcinoma
# 3     infiltrating ductal carcinoma
# 4     infiltrating ductal carcinoma
# ..                              ...
# 644   infiltrating ductal carcinoma
# 645   infiltrating ductal carcinoma
# 647   infiltrating ductal carcinoma
# 648   infiltrating ductal carcinoma
# 649  infiltrating lobular carcinoma
#
# [516 rows x 1941 columns]

# %%
#Import the cleaned_dataset into local system
df_cleaned.to_csv('cleaned_data.csv', index=False)

# %%
#identifying garbage values
for i in df_further_cleaned.select_dtypes(include="object").columns:
    print(df_further_cleaned[i].value_counts())
    print("***"*10)
# Out:
# PR.Status
# Positive    336
# Negative    180
# Name: count, dtype: int64
# ******************************
# ER.Status
# Positive    391
# Negative    125
# Name: count, dtype: int64
# ******************************
# HER2.Final.Status
# Negative     425
# Positive      82
# Equivocal      9
# Name: count, dtype: int64
# ******************************
# histological.type
# infiltrating ductal carcinoma     466
# infiltrating lobular carcinoma     50
# Name: count, dtype: int64
# ******************************

# %%
# This creates a new DataFrame that excludes rows where 'HER2.Final.Status' is 'Equivocal'.
df_final = df_further_cleaned[df_further_cleaned['HER2.Final.Status'] != 'Equivocal']


# --- Display the Result ---
print("DataFrame After Removal:")
print(df_final)
# Out:
# DataFrame After Removal:
#      rs_CLEC3A    rs_CPB1  rs_SCGB2A2  rs_SCGB1D2    rs_TFF1   rs_MUCL1  \
# 0     0.892818   6.580103   14.123672   10.606501  13.189237   6.649466
# 1     0.000000   3.691311   17.116090   15.517231   9.867616   9.691667
# 2     3.748150   4.375255    9.658123    5.326983  12.109539  11.644307
# 3     0.000000  18.235519   18.535480   14.533584  14.078992   8.913760
# 4     0.000000   4.583724   15.711865   12.804521   8.881669   8.430028
# ..         ...        ...         ...         ...        ...        ...
# 644   0.000000  14.652475    6.430018    2.487152  10.896235   2.487152
# 645   0.000000   4.071531    3.128508    5.467426   0.000000   0.718438
# 647   3.186199  11.624534    8.096817    4.858956   9.683010   9.276432
# 648  15.582967  10.151592   15.638541   14.126165  12.447517  16.541921
# 649   0.000000   5.093780   15.999704   13.844006  11.539494  13.139496
#
#       rs_GSTM1     rs_PIP  rs_ADIPOQ   rs_ADH1B  ...  pp_p62.LCK.ligand  \
# 0    10.520335  10.338490  10.248379  10.229970  ...          -0.691766
# 1     8.179522   7.911723   1.289598   1.818891  ...           0.279067
# 2    10.517330   5.114925  11.975349  11.911437  ...           0.219910
# 3    10.557465  13.304434   8.205059   9.211476  ...          -0.266554
# 4    12.964607   6.806517   4.294341   5.385714  ...          -0.441542
# ..         ...        ...        ...        ...  ...                ...
# 644   1.507262   3.591691   9.853473   8.579071  ...           0.143937
# 645   7.640049   2.959232   0.718438   0.000000  ...           0.866684
# 647   0.000000   4.104681  10.952462  10.785635  ...          -0.506134
# 648   2.528146  12.756991   7.870444   7.952345  ...           0.720128
# 649   1.073820  13.300868   6.095994   7.043729  ...          -0.160632
#
#      pp_p70S6K  pp_p70S6K.pT389  pp_p90RSK  pp_p90RSK.pT359.S363  \
# 0    -0.337863        -0.178503   0.011638             -0.207257
# 1     0.292925        -0.155242  -0.089365              0.267530
# 2     0.308110        -0.190794  -0.222150             -0.198518
# 3    -0.079871        -0.463237   0.522998             -0.046902
# 4    -0.152317         0.511386  -0.096482              0.037473
# ..         ...              ...        ...                   ...
# 644  -0.187309        -0.005034  -0.511851              0.010582
# 645  -0.362491        -0.225097  -0.098282             -0.057920
# 647  -0.369786         0.967447  -0.201545              0.482839
# 648  -0.208679         0.003550  -0.254628             -0.092632
# 649  -0.688076         0.067496  -0.018579              0.072714
#
#      vital.status  PR.Status  ER.Status  HER2.Final.Status  \
# 0               0   Positive   Positive           Negative
# 1               0   Positive   Negative           Negative
# 2               0   Positive   Positive           Negative
# 3               0   Positive   Positive           Negative
# 4               0   Positive   Positive           Negative
# ..            ...        ...        ...                ...
# 644             0   Positive   Positive           Negative
# 645             0   Negative   Negative           Negative
# 647             0   Positive   Positive           Positive
# 648             0   Positive   Positive           Negative
# 649             0   Positive   Positive           Negative
#
#                   histological.type
# 0     infiltrating ductal carcinoma
# 1     infiltrating ductal carcinoma
# 2     infiltrating ductal carcinoma
# 3     infiltrating ductal carcinoma
# 4     infiltrating ductal carcinoma
# ..                              ...
# 644   infiltrating ductal carcinoma
# 645   infiltrating ductal carcinoma
# 647   infiltrating ductal carcinoma
# 648   infiltrating ductal carcinoma
# 649  infiltrating lobular carcinoma
#
# [507 rows x 1941 columns]

# %%
# 1. Create a dictionary to define the mapping.
type_mapping = {
    'Infiltrating Ductal Carcinoma': 0,
    'Infiltrating Lobular Carcinoma': 1
}

# 2. Use the .map() function to apply the mapping.
# This line will now work without a warning
df_final['histological.type'] = df_final['histological.type'].map(type_mapping)

# --- Display the Result ---
print("DataFrame After Label Encoding:")
print(df_final)
# Out:
# DataFrame After Label Encoding:
#      rs_CLEC3A    rs_CPB1  rs_SCGB2A2  rs_SCGB1D2    rs_TFF1   rs_MUCL1  \
# 0     0.892818   6.580103   14.123672   10.606501  13.189237   6.649466
# 1     0.000000   3.691311   17.116090   15.517231   9.867616   9.691667
# 2     3.748150   4.375255    9.658123    5.326983  12.109539  11.644307
# 3     0.000000  18.235519   18.535480   14.533584  14.078992   8.913760
# 4     0.000000   4.583724   15.711865   12.804521   8.881669   8.430028
# ..         ...        ...         ...         ...        ...        ...
# 644   0.000000  14.652475    6.430018    2.487152  10.896235   2.487152
# 645   0.000000   4.071531    3.128508    5.467426   0.000000   0.718438
# 647   3.186199  11.624534    8.096817    4.858956   9.683010   9.276432
# 648  15.582967  10.151592   15.638541   14.126165  12.447517  16.541921
# 649   0.000000   5.093780   15.999704   13.844006  11.539494  13.139496
#
#       rs_GSTM1     rs_PIP  rs_ADIPOQ   rs_ADH1B  ...  pp_p62.LCK.ligand  \
# 0    10.520335  10.338490  10.248379  10.229970  ...          -0.691766
# 1     8.179522   7.911723   1.289598   1.818891  ...           0.279067
# 2    10.517330   5.114925  11.975349  11.911437  ...           0.219910
# 3    10.557465  13.304434   8.205059   9.211476  ...          -0.266554
# 4    12.964607   6.806517   4.294341   5.385714  ...          -0.441542
# ..         ...        ...        ...        ...  ...                ...
# 644   1.507262   3.591691   9.853473   8.579071  ...           0.143937
# 645   7.640049   2.959232   0.718438   0.000000  ...           0.866684
# 647   0.000000   4.104681  10.952462  10.785635  ...          -0.506134
# 648   2.528146  12.756991   7.870444   7.952345  ...           0.720128
# 649   1.073820  13.300868   6.095994   7.043729  ...          -0.160632
#
#      pp_p70S6K  pp_p70S6K.pT389  pp_p90RSK  pp_p90RSK.pT359.S363  \
# 0    -0.337863        -0.178503   0.011638             -0.207257
# 1     0.292925        -0.155242  -0.089365              0.267530
# 2     0.308110        -0.190794  -0.222150             -0.198518
# 3    -0.079871        -0.463237   0.522998             -0.046902
# 4    -0.152317         0.511386  -0.096482              0.037473
# ..         ...              ...        ...                   ...
# 644  -0.187309        -0.005034  -0.511851              0.010582
# 645  -0.362491        -0.225097  -0.098282             -0.057920
# 647  -0.369786         0.967447  -0.201545              0.482839
# 648  -0.208679         0.003550  -0.254628             -0.092632
# 649  -0.688076         0.067496  -0.018579              0.072714
#
#      vital.status  PR.Status  ER.Status  HER2.Final.Status  histological.type
# 0               0   Positive   Positive           Negative                NaN
# 1               0   Positive   Negative           Negative                NaN
# 2               0   Positive   Positive           Negative                NaN
# 3               0   Positive   Positive           Negative                NaN
# 4               0   Positive   Positive           Negative                NaN
# ..            ...        ...        ...                ...                ...
# 644             0   Positive   Positive           Negative                NaN
# 645             0   Negative   Negative           Negative                NaN
# 647             0   Positive   Positive           Positive                NaN
# 648             0   Positive   Positive           Negative                NaN
# 649             0   Positive   Positive           Negative                NaN
#
# [507 rows x 1941 columns]
# C:\Users\samee\AppData\Local\Temp\ipykernel_26628\2230271583.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['histological.type'] = df_final['histological.type'].map(type_mapping)
